# %%
import base

import pandas as pd
import json
from collections import namedtuple
import re
import ngender
import time

# %%
# my private modules
import fund_scanner.database
import fund_scanner.readurl

# %%
#page=page_index,items_in_one_page

url = 'http://fund.eastmoney.com/Data/FundRankScale.aspx?v=%f'%time.time()

body = fund_scanner.readurl.read_from_url(url)

# %%
insider = re.search('\[\[(.*?)\]\]', body).group(1)
insider = insider.replace('\'', '"')
insider = '{"main":[['+insider+']]}'
obj = json.loads(insider, object_hook=lambda d: namedtuple('X', d.keys())(*d.values()))
df =pd.DataFrame(obj.main)
df.sort_values(by=2)
df = df.loc[:,[0,1,2,7,9]]
df.columns = ['companies_code', 'companies_name_full', 'companies_start_date', 'companies_size', 'companies_name_short']

df
# Out:
#     companies_code companies_name_full companies_start_date companies_size  \
# 0         80036782          招商基金管理有限公司           2002-12-27        3713.23
# 1         80351991          鑫元基金管理有限公司           2013-08-29         367.37
# 2         80175498          英大基金管理有限公司           2012-08-17          21.85
# 3         80068180          诺德基金管理有限公司           2006-06-08          70.47
# 4         80050229        上投摩根基金管理有限公司           2004-05-12        1229.57
# 5         80037023          华富基金管理有限公司           2004-04-19         420.21
# 6         80366080          上银基金管理有限公司           2013-08-30         372.44
# 7         80404004    长江证券(上海)资产管理有限公司           2014-09-16          54.21
# 8         80380794        创金合信基金管理有限公司           2014-07-09         155.66
# 9         80488954          富荣基金管理有限公司           2016-01-25          25.49
# 10        80000231          融通基金管理有限公司           2001-05-22         651.62
# 11        80355783        国寿安保基金管理有限公司           2013-10-29        1004.48
# 12        80205264          江信基金管理有限公司           2013-01-28          33.32
# 13        80000080          山西证券股份有限公司           1988-07-28          40.33
# 14        80280395          兴业基金管理有限公司           2013-04-17        1461.35
# 15        80446423          金信基金管理有限公司           2015-07-03          11.70
# 16        80042861        东方基金管理有限责任公司           2004-06-11         193.53
# 17        80074234        信达澳银基金管理有限公司           2006-06-05         167.83
# 18        80391977    华泰证券(上海)资产管理有限公司           2014-10-16
# 19        80053708       汇添富基金管理股份有限公司           2005-02-03        2885.84
# 20        80555446          南华基金管理有限公司           2016-11-17
# 21        80522693          鹏扬基金管理有限公司           2016-07-06          31.67
# 22        80199117        华润元大基金管理有限公司           2013-01-17          19.96
# 23        80000246         海富通基金管理有限公司           2003-04-18         486.83
# 24        80147736        西部利得基金管理有限公司           2010-07-20         229.52
# 25        80000223          嘉实基金管理有限公司           1999-03-25        3437.47
# 26        80000227          长盛基金管理有限公司           1999-03-26         676.95
# 27        80066470          信诚基金管理有限公司           2005-09-30         723.56
# 28        80075936      中邮创业基金管理股份有限公司           2006-05-08         519.44
# 29        80000239          长城基金管理有限公司           2001-12-27         681.97
# ..             ...                 ...                  ...            ...
# 96        80114781          东兴证券股份有限公司           2008-05-28          98.14
# 97        80538609      渤海汇金证券资产管理有限公司           2016-05-18          23.33
# 98        80508391          中航基金管理有限公司           2016-06-16           3.89
# 99        80403111      浙江浙商证券资产管理有限公司           2013-04-18          12.75
# 100       80294346          太平基金管理有限公司           2013-01-23         166.78
# 101       80000235        银华基金管理股份有限公司           2001-05-28        1543.49
# 102       80000240          万家基金管理有限公司           2002-08-23         620.99
# 103       80064562       交银施罗德基金管理有限公司           2005-08-04         882.34
# 104       80044515      国海富兰克林基金管理有限公司           2004-11-15         250.27
# 105       80048161          东吴基金管理有限公司           2004-09-02         247.63
# 106       80000229         易方达基金管理有限公司           2001-04-17        4747.53
# 107       80163340        安信基金管理有限责任公司           2011-12-06         285.08
# 108       80341238          中融基金管理有限公司           2013-05-31         413.45
# 109       80041198          天弘基金管理有限公司           2004-11-08       15185.65
# 110       80000233        国投瑞银基金管理有限公司           2002-06-13         794.12
# 111       80061431        中国人保资产管理有限公司           2003-07-16
# 112       80501166          先锋基金管理有限公司           2016-05-16          21.64
# 113       80000222          华夏基金管理有限公司           1998-04-09        3282.21
# 114       80365987          嘉合基金管理有限公司           2014-07-30         104.69
# 115       80000095          国都证券股份有限公司           2001-12-28           8.11
# 116       80000247          泰信基金管理有限公司           2003-05-23          50.08
# 117       80356155          永赢基金管理有限公司           2013-11-07         630.93
# 118       80384640          九泰基金管理有限公司           2014-07-03         123.94
# 119       80048088       光大保德信基金管理有限公司           2004-04-22         662.21
# 120       80000250        华宝兴业基金管理有限公司           2003-03-07        1228.51
# 121       80000251        景顺长城基金管理有限公司           2003-06-12         737.56
# 122       80056613        北京高华证券有限责任公司           2004-10-18
# 123       80560389          国融基金管理有限公司           2017-06-20
# 124       80560381          凯石基金管理有限公司           2017-05-10
# 125       80560392          博道基金管理有限公司           2017-06-12
#
#     companies_name_short
# 0                   招商基金
# 1                   鑫元基金
# 2                   英大基金
# 3                   诺德基金
# 4                 上投摩根基金
# 5                   华富基金
# 6                   上银基金
# 7               长江证券(上海)
# 8                 创金合信基金
# 9                   富荣基金
# 10                  融通基金
# 11                国寿安保基金
# 12                  江信基金
# 13                  山西证券
# 14                  兴业基金
# 15                  金信基金
# 16                  东方基金
# 17                信达澳银基金
# 18              华泰证券(上海)
# 19                 汇添富基金
# 20                  南华基金
# 21                  鹏扬基金
# 22                华润元大基金
# 23                 海富通基金
# 24                西部利得基金
# 25                  嘉实基金
# 26                  长盛基金
# 27                  信诚基金
# 28                  中邮基金
# 29                  长城基金
# ..                   ...
# 96                  东兴证券
# 97                  渤海汇金
# 98                  中航基金
# 99                浙商证券资管
# 100                 太平基金
# 101                 银华基金
# 102                 万家基金
# 103              交银施罗德基金
# 104             国海富兰克林基金
# 105                 东吴基金
# 106                易方达基金
# 107                 安信基金
# 108                 中融基金
# 109                 天弘基金
# 110               国投瑞银基金
# 111                 人保资产
# 112                 先锋基金
# 113                 华夏基金
# 114                 嘉合基金
# 115                 国都证券
# 116                 泰信基金
# 117                 永赢基金
# 118                 九泰基金
# 119              光大保德信基金
# 120               华宝兴业基金
# 121               景顺长城基金
# 122                 高华证券
# 123                 国融基金
# 124                 凯石基金
# 125                 博道基金
#
# [126 rows x 5 columns]

# %%
with fund_scanner.database.get_connection() as cursor:

    for index, row in df.iterrows():
        #print(row['净值日期'])
        sql = 'INSERT INTO companies '+\
        '(companies_name_full, companies_name_short, companies_code, companies_start_date, companies_size) '+\
        'VALUES (%s,%s,%s,%s,%s) ON DUPLICATE KEY UPDATE '+\
        'companies_name_full=%s, companies_name_short=%s, companies_size=%s;'

        cursor.execute(
            sql, (
                row['companies_name_full'],
                row['companies_name_short'], 
                row['companies_code'],
                row['companies_start_date'], 
                base.extract_float(row, 'companies_size'),
                row['companies_name_full'], 
                row['companies_name_short'],
                base.extract_float(row, 'companies_size')
            )
        )

# %%
# %matplotlib inline
import pandas as pd
import sqlalchemy
import matplotlib.pyplot as plt
c = sqlalchemy.create_engine("mysql+pymysql://funds:funds888@localhost/funds?charset=utf8")

# %%
df = pd.read_sql('SELECT * FROM funds a left join funds_update b on a.funds_id=b.funds_id where a.funds_type is not null',c)
df
# Out:
#       funds_id funds_code funds_name_full funds_type funds_start_date  \
# 0           92     003011         中融盈润债券A        债券型       2017-03-29
# 1           93     501025   鹏华香港银行指数(LOF)       股票指数       2016-11-10
# 2           94     398041        中海量化策略混合        混合型       2009-06-24
# 3           95     001223      鹏华文化传媒娱乐股票        股票型       2016-01-27
# 4           96     540010        汇丰晋信科技先锋        股票型       2011-07-27
# 5           97     001596           信诚新泽A        混合型       2017-06-27
# 6           98     161726    招商国证生物医药指数分级       股票指数       2015-05-27
# 7           99     501009    汇添富中证生物科技指数A       股票指数       2016-12-22
# 8          100     501010    汇添富中证生物科技指数C       股票指数       2016-12-22
# 9          101     001888  中欧盛世成长混合(LOF)E        混合型       2015-10-08
# 10         142     001307         中欧永裕混合C        混合型       2015-06-04
# 11         143     166011  中欧盛世成长混合(LOF)A        混合型       2012-03-29
# ...

# %%
df = df.loc[:,:'funds_return_adjust_per_year']
df.columns
# Out:
# Index(['funds_id', 'funds_code', 'funds_name_full', 'funds_type',
#        'funds_start_date', 'update_time', 'historical_price_time',
#        'funds_update_id', 'funds_id', 'funds_price', 'funds_price_adjust',
#        'funds_amount', 'funds_recent_1_month', 'funds_recent_3_month',
#        'funds_recent_6_month', 'funds_recent_1_year', 'funds_recent_3_year',
#        'funds_return_total', 'funds_return_adjust_per_year'],
#       dtype='object')

# %%
weight = [6,3,2,1,1,1]
df['score'] = df['funds_recent_1_month'] * weight[0] + (df['funds_recent_3_month']-df['funds_recent_1_month']) * weight[1] + (df['funds_recent_6_month']-df['funds_recent_3_month']) * weight[3]


df[df['funds_amount']>1].sort_values(by='score', ascending=False)
# Out:
#       funds_id funds_code funds_name_full funds_type funds_start_date  \
# 763        895     180028          银华永祥保本        保本型       2011-06-28
# 746        878     001387        中融新经济混合A        混合型       2015-11-17
# 832        964     001840         招商丰享混合C        混合型       2015-11-17
# 41         173     165520   信诚中证800有色指数分级       股票指数       2013-08-30
# 346        478     161724    招商中证煤炭等权指数分级       股票指数       2015-05-20
# 872       1004     003039         广发集富纯债A        债券型       2017-01-13
# 2029      2162     240022        华宝资源优选混合        混合型       2012-08-21
# 2242      2375     110025       易方达资源行业混合        混合型       2011-08-16
# 815        947     161032      富国中证煤炭指数分级       股票指数       2015-06-19
# 2809      2942     202211          南方恒元保本        保本型       2008-11-12
# 401        533     003857     前海开源周期优选混合A        混合型       2017-01-25
# 2193      2326     161715     招商大宗商品(LOF)       股票指数       2012-06-28
# ...
